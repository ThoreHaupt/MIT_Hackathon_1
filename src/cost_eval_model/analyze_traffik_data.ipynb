# %%
import pandas as pd

# %%
path = "/home/thore/Downloads/2022_A_S.txt"
df = pd.read_csv(path, sep=";", header=0, )
# Out:
#     TKNR   Zst  Land Strklas  Strnum   Datum  Wotag Fahrtzw  Stunde  KFZ_R1  \
# 0   7016  8001     8       A       5  220101      6       s       1     201
# 1   7016  8001     8       A       5  220101      6       s       2     450
# 2   7016  8001     8       A       5  220101      6       s       3     334
# 3   7016  8001     8       A       5  220101      6       s       4     228
# 4   7016  8001     8       A       5  220101      6       s       5     157
# 5   7016  8001     8       A       5  220101      6       s       6     163
# 6   7016  8001     8       A       5  220101      6       s       7     165
# 7   7016  8001     8       A       5  220101      6       s       8     196
# 8   7016  8001     8       A       5  220101      6       s       9     289
# 9   7016  8001     8       A       5  220101      6       s      10     536
# 10  7016  8001     8       A       5  220101      6       s      11     960
# ...

# %%
df.head(20)
# Out:
#     TKNR   Zst  Land Strklas  Strnum   Datum  Wotag Fahrtzw  Stunde  KFZ_R1  \
# 0   7016  8001     8       A       5  220101      6       s       1     201
# 1   7016  8001     8       A       5  220101      6       s       2     450
# 2   7016  8001     8       A       5  220101      6       s       3     334
# 3   7016  8001     8       A       5  220101      6       s       4     228
# 4   7016  8001     8       A       5  220101      6       s       5     157
# 5   7016  8001     8       A       5  220101      6       s       6     163
# 6   7016  8001     8       A       5  220101      6       s       7     165
# 7   7016  8001     8       A       5  220101      6       s       8     196
# 8   7016  8001     8       A       5  220101      6       s       9     289
# 9   7016  8001     8       A       5  220101      6       s      10     536
# 10  7016  8001     8       A       5  220101      6       s      11     960
# ...
